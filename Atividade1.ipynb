# %% [markdown]
# <a href="https://colab.research.google.com/github/sanchesprogramer/Ciencia-de-dados/blob/main/Atividade1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carrega o DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/sanchesprogramer/Ciencia-de-dados/main/trab11.csv', encoding='UTF-8', sep=';')

# Imprime os nomes das colunas
print("Nomes das colunas no DataFrame:")
print(df.columns)

# Imprime a quantidade de objetos (linhas) e atributos (colunas)
print(f"Quantidade de objetos (linhas): {df.shape[0]}")
print(f"Quantidade de atributos (colunas): {df.shape[1]}")

# Imprime os tipos de dados dos atributos
print("\nTipos de dados dos atributos:")
print(df.dtypes)

# Análise estatística dos atributos numéricos
print("\nAnálise estatística dos atributos numéricos:")
print(df.describe().T)

# Boxplot das variáveis numéricas
numerical_vars = ['Custo (R$)', 'Movimentação']
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[numerical_vars])
plt.title('Boxplot de Variáveis Numéricas')
plt.show()

# Gráfico de barras para a variável categórica
categorical_var = 'Curva'
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x=categorical_var)
plt.title('Gráfico de Barras de Variável Categórica')
plt.show()
# Out:
# Nomes das colunas no DataFrame:
# Index(['Curva', 'Tipo_De_Material', 'Setor_Industrial', 'Unidade_Volume',
#        'Custo (R$)', 'Movimentação', 'Movimentação X Custo'],
#       dtype='object')
# Quantidade de objetos (linhas): 130
# Quantidade de atributos (colunas): 7
#
# Tipos de dados dos atributos:
# Curva                   object
# Tipo_De_Material        object
# Setor_Industrial        object
# Unidade_Volume          object
# Custo (R$)               int64
# Movimentação             int64
# Movimentação X Custo     int64
# dtype: object
#
# Análise estatística dos atributos numéricos:
#                       count          mean           std     min       25%  \
# Custo (R$)            130.0  1.647246e+03  1.930024e+03    25.0     76.25
# Movimentação          130.0  6.321769e+02  2.375278e+02   123.0    456.00
# Movimentação X Custo  130.0  1.032402e+06  1.358705e+06  7488.0  49365.00
#
#                            50%         75%        max
# Custo (R$)               250.0     2050.00     5500.0
# Movimentação             678.0      854.25      987.0
# Movimentação X Custo  216370.0  1568137.50  5033700.0
